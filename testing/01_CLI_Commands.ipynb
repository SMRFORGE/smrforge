# %% [markdown]
# # CLI Commands Testing
#
# This notebook tests all CLI commands available in SMRForge.
#
# ## Instructions
# 1. Run each cell in order
# 2. Check that commands execute without errors
# 3. Verify output is correct and helpful
# 4. Note any issues or unclear messages
#
# ## Test Results
# - [ ] Basic help works
# - [ ] Reactor commands work
# - [ ] Data commands work
# - [ ] Burnup commands work
# - [ ] Validation commands work
# - [ ] Visualization commands work
# - [ ] Config commands work
# - [ ] Shell command works
# - [ ] Workflow command works
# - [ ] Sweep command works
# - [ ] Template commands work
# - [ ] I/O converter commands work

# %% [markdown]
# ## 1. Basic Help and Version

# %%
# Check SMRForge version (FIXED - --version flag now works)
# !smrforge --version
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/smrforge", line 7, in <module>
#     sys.exit(main())
#              ^^^^^^
#   File "/app/smrforge/cli.py", line 2460, in main
#     validate_parser = subparsers.add_parser(
#                       ^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/argparse.py", line 1197, in add_parser
#     raise ArgumentError(self, _('conflicting subparser: %s') % name)
# argparse.ArgumentError: argument command: conflicting subparser: validate

# %%
# Show main help
# !smrforge --help
